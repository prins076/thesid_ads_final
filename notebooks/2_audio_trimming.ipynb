# %%
import json
import pandas as pd
import subprocess
import time

from pydub import AudioSegment
from tqdm import tqdm

WAV_OUTPUT_DIR = '../data/processed/wav/'

# %% [markdown]
# # Video data

# %%
df_videos = pd.read_csv('../data/processed/videos_with_segmented_audio.csv')
df_videos.drop_duplicates(subset=['id'], inplace=True)
df_videos.head()
# Out:
#   search_tag                           video_path  video_classes
# 0  biden2020  data/videos/6892193566290889985.mp4            NaN  \
# 1  biden2020  data/videos/6839079433794505989.mp4            NaN
# 2  biden2020  data/videos/6885403130297732357.mp4            NaN
# 3  biden2020  data/videos/6889924077721521413.mp4            NaN
# 4  biden2020  data/videos/6891017029051108614.mp4            NaN
#
#                     id                                               desc
# 0  6892193566290889985  We'll be right, thanks. New Zealand.. anyone? ...  \
# 1  6839079433794505989  Reply to @nickh1940 #repost share this so more...
# 2  6885403130297732357  anyways vote biden💙#fyp #foryou #foryoupage #b...
# 3  6889924077721521413              Oh my god Barack Obama 🥵🥵🥵 #biden2020
# 4  6891017029051108614  Reply to @taybarnett262  IDK HOW TO FEEL RN HE...
#
#    create_time  is_duet_enabled
# 0   1604713867             True  \
# 1   1592347270             True
# 2   1603132900            False
# 3   1604185495             True
# 4   1604439965             True
#
#                                             hashtags
# 0         bidenharris2020, straya, aussie, biden2020  \
# 1  , repost, trump, viral, fyp, foryoupage, parat...
# 2                 fyp, foryou, foryoupage, biden2020
# 3                                          biden2020
# 4          , fyp, election2020, biden2020, trump2020
#
#                                                cover
# 0  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  \
# 1  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 2  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 3  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 4  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
#
#                                         play_address  ...
# 0  https://v16-webapp-prime.tiktok.com/video/tos/...  ...  \
# 1  https://v16-webapp-prime.tiktok.com/video/tos/...  ...
# 2  https://v16-webapp-prime.tiktok.com/video/tos/...  ...
# 3  https://v16-webapp-prime.tiktok.com/video/tos/...  ...
# 4  https://v16-webapp-prime.tiktok.com/video/tos/...  ...
#
#   author_followers_count  author_heart_count author_digg_count  author_heart
# 0                1800000            82800000              7080      82800000  \
# 1                 208200             6600000              9305       6600000
# 2                 236200            15700000            100400      15700000
# 3                2200000            81400000             14300      81400000
# 4                 206100             6200000             78000       6200000
#
#   video_contains_music video_contains_male video_contains_female
# 0                 True                True                  True  \
# 1                 True                True                 False
# 2                 True               False                 False
# 3                 True               False                 False
# 4                 True                True                  True
#
#    video_contains_noise  video_contains_no_energy
# 0                 False                      True  \
# 1                 False                     False
# 2                 False                     False
# 3                  True                     False
# 4                  True                      True
#
#                                             segments
# 0  [{'label': 'music', 'start': 0.0, 'end': 3.86}...
# 1  [{'label': 'music', 'start': 0.0, 'end': 1.54}...
# 2    [{'label': 'music', 'start': 0.0, 'end': 6.54}]
# 3  [{'label': 'noise', 'start': 0.0, 'end': 3.9},...
# 4  [{'label': 'music', 'start': 0.0, 'end': 14.88...
#
# [5 rows x 40 columns]

# %% [markdown]
# # Checking what percentage of the video is made of music

# %%
audio_segments_df = pd.read_csv('../data/processed/video_audio_segments.csv')
audio_segments_df['total_duration'] = audio_segments_df['end'] - audio_segments_df['start']

# Grouping by video_id and label
grouped_audio_segments = audio_segments_df.groupby(['video_id', 'label']).agg({'total_duration': 'sum'})
grouped_audio_segments = grouped_audio_segments.reset_index()

videos_with_music = grouped_audio_segments.loc[grouped_audio_segments['label'] == 'music', ['video_id', 'total_duration']]
videos_with_music.columns = ['video_id', 'total_music_duration']
videos_with_music.head()
# Out:
#                video_id  total_music_duration
# 2   6748605663171136773                 10.90
# 3   6750663345616981253                 14.98
# 5   6752944407395175686                  4.54
# 9   6755172553632926981                 16.22
# 11  6756623980511137026                 10.28

# %% [markdown]
# # Merging dataframe with audio segment

# %%
df_merged_videos_annotations = df_videos.merge(videos_with_music, left_on='id', right_on='video_id', how='left')
df_merged_videos_annotations = df_merged_videos_annotations.drop(['video_id'], axis=1)

# Calculating percentage of music in video
df_merged_videos_annotations['total_music_duration'] = df_merged_videos_annotations['total_music_duration'].fillna(0)
df_merged_videos_annotations['percentage_of_video_made_of_music'] = df_merged_videos_annotations['total_music_duration'] * 100.00 / df_merged_videos_annotations['duration']
df_merged_videos_annotations.set_index('id', inplace=True)
df_merged_videos_annotations.head()
# Out:
#                     search_tag                           video_path
# id
# 6892193566290889985  biden2020  data/videos/6892193566290889985.mp4  \
# 6839079433794505989  biden2020  data/videos/6839079433794505989.mp4
# 6885403130297732357  biden2020  data/videos/6885403130297732357.mp4
# 6889924077721521413  biden2020  data/videos/6889924077721521413.mp4
# 6891017029051108614  biden2020  data/videos/6891017029051108614.mp4
#
#                      video_classes
# id
# 6892193566290889985            NaN  \
# 6839079433794505989            NaN
# 6885403130297732357            NaN
# 6889924077721521413            NaN
# 6891017029051108614            NaN
#
#                                                                   desc
# id
# 6892193566290889985  We'll be right, thanks. New Zealand.. anyone? ...  \
# 6839079433794505989  Reply to @nickh1940 #repost share this so more...
# 6885403130297732357  anyways vote biden💙#fyp #foryou #foryoupage #b...
# 6889924077721521413              Oh my god Barack Obama 🥵🥵🥵 #biden2020
# 6891017029051108614  Reply to @taybarnett262  IDK HOW TO FEEL RN HE...
#
#                      create_time  is_duet_enabled
# id
# 6892193566290889985   1604713867             True  \
# 6839079433794505989   1592347270             True
# 6885403130297732357   1603132900            False
# 6889924077721521413   1604185495             True
# 6891017029051108614   1604439965             True
#
#                                                               hashtags
# id
# 6892193566290889985         bidenharris2020, straya, aussie, biden2020  \
# 6839079433794505989  , repost, trump, viral, fyp, foryoupage, parat...
# 6885403130297732357                 fyp, foryou, foryoupage, biden2020
# 6889924077721521413                                          biden2020
# 6891017029051108614          , fyp, election2020, biden2020, trump2020
#
#                                                                  cover
# id
# 6892193566290889985  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  \
# 6839079433794505989  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 6885403130297732357  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 6889924077721521413  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 6891017029051108614  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
#
#                                                           play_address
# id
# 6892193566290889985  https://v16-webapp-prime.tiktok.com/video/tos/...  \
# 6839079433794505989  https://v16-webapp-prime.tiktok.com/video/tos/...
# 6885403130297732357  https://v16-webapp-prime.tiktok.com/video/tos/...
# 6889924077721521413  https://v16-webapp-prime.tiktok.com/video/tos/...
# 6891017029051108614  https://v16-webapp-prime.tiktok.com/video/tos/...
#
#                                                       download_address  ...
# id                                                                      ...
# 6892193566290889985  https://v16-webapp-prime.tiktok.com/video/tos/...  ...  \
# 6839079433794505989  https://v16-webapp-prime.tiktok.com/video/tos/...  ...
# 6885403130297732357  https://v16-webapp-prime.tiktok.com/video/tos/...  ...
# 6889924077721521413  https://v16-webapp-prime.tiktok.com/video/tos/...  ...
# 6891017029051108614  https://v16-webapp-prime.tiktok.com/video/tos/...  ...
#
#                      author_digg_count author_heart  video_contains_music
# id
# 6892193566290889985               7080     82800000                  True  \
# 6839079433794505989               9305      6600000                  True
# 6885403130297732357             100400     15700000                  True
# 6889924077721521413              14300     81400000                  True
# 6891017029051108614              78000      6200000                  True
#
#                     video_contains_male video_contains_female
# id
# 6892193566290889985                True                  True  \
# 6839079433794505989                True                 False
# 6885403130297732357               False                 False
# 6889924077721521413               False                 False
# 6891017029051108614                True                  True
#
#                     video_contains_noise  video_contains_no_energy
# id
# 6892193566290889985                False                      True  \
# 6839079433794505989                False                     False
# 6885403130297732357                False                     False
# 6889924077721521413                 True                     False
# 6891017029051108614                 True                      True
#
#                                                               segments
# id
# 6892193566290889985  [{'label': 'music', 'start': 0.0, 'end': 3.86}...  \
# 6839079433794505989  [{'label': 'music', 'start': 0.0, 'end': 1.54}...
# 6885403130297732357    [{'label': 'music', 'start': 0.0, 'end': 6.54}]
# 6889924077721521413  [{'label': 'noise', 'start': 0.0, 'end': 3.9},...
# 6891017029051108614  [{'label': 'music', 'start': 0.0, 'end': 14.88...
#
#                      total_music_duration  percentage_of_video_made_of_music
# id
# 6892193566290889985                  3.86                          13.310345
# 6839079433794505989                  1.54                           6.695652
# 6885403130297732357                  6.54                         109.000000
# 6889924077721521413                 12.84                          80.250000
# 6891017029051108614                 14.88                          26.105263
#
# [5 rows x 41 columns]

# %% [markdown]
# # Trimming audio containing only male and female voice

# %%
successful_audios_with_voice = 0
for video_id in tqdm(df_merged_videos_annotations.index):
    video = df_merged_videos_annotations.loc[[video_id]]
    video_id = video_id

    video_filename = '../' + video['video_path'].values[0]

    audio_voice_segments = audio_segments_df.loc[(audio_segments_df['video_id'] == video_id) & 
                                                 (audio_segments_df['label'].isin(['male', 'female']))].copy()
    audio_voice_segments.loc[:, 'next_start'] = audio_voice_segments.loc[:, 'start'].shift(-1)

    audio = AudioSegment.from_file(video_filename)
    trimmed_audio_voices = []

    audio_start = audio_voice_segments['start'].min() * 1000
    for idx, row in audio_voice_segments.iterrows():
        if row['next_start'] < row['end'] + 1:
            continue

        start = audio_start        
        end = (row['end'] + 1) * 1000
        if len(trimmed_audio_voices) == 0:
            trimmed_audio_voices = audio[start:end]
        else:
            trimmed_audio_voices = trimmed_audio_voices + audio[start:end]

        audio_start = row['next_start'] * 1000

    if len(trimmed_audio_voices) > 0:
        trimmed_audio_voices.export(f"../data/audios/{video_id}.mp3", format="mp3")
        successful_audios_with_voice += 1
# Out:
# 100%|██████████| 2029/2029 [10:06<00:00,  3.35it/s]

# %% [markdown]
# # Saving transcripted video

# %%
df_merged_videos_annotations.to_csv('../data/processed/transcripted_processed_videos.csv')
