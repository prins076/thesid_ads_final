# %%
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# # Loading data
# ## Loading whisper transcribed data

# %%
df_transcripted_videos = pd.read_csv('../data/processed/transcripted_audios.csv')
print(df_transcripted_videos.shape)
df_transcripted_videos.head()
# Out:
# (1185, 3)
#                              audio_id
# 0  ../data/audios\6746590978280279301  \
# 1  ../data/audios\6748582567995378949
# 2  ../data/audios\6752944407395175686
# 3  ../data/audios\6755172553632926981
# 4  ../data/audios\6758547542276852998
#
#                                        transcription detected_language
# 0  Do you know what Dab Me Up is? Do you know wha...                en
# 1  Go ahead, go ahead. No, not you, not you. Your...                en
# 2                                   There's not any.                en
# 3  If I give you one message to hold in your hear...                en
# 4    What? Did I kill them, sir? Are you kidding me?                en

# %%
# fixing the audio_id column
df_transcripted_videos['audio_id'] = df_transcripted_videos['audio_id'].str.split('\\').str[-1]
df_transcripted_videos['audio_id'] = df_transcripted_videos['audio_id'].astype('Int64')
df_transcripted_videos.head()
# Out:
#               audio_id                                      transcription
# 0  6746590978280279301  Do you know what Dab Me Up is? Do you know wha...  \
# 1  6748582567995378949  Go ahead, go ahead. No, not you, not you. Your...
# 2  6752944407395175686                                   There's not any.
# 3  6755172553632926981  If I give you one message to hold in your hear...
# 4  6758547542276852998    What? Did I kill them, sir? Are you kidding me?
#
#   detected_language
# 0                en
# 1                en
# 2                en
# 3                en
# 4                en

# %% [markdown]
# ## Parsed data

# %%
df_parsed_data = pd.read_csv('../data/processed/transcripted_processed_videos.csv')
print(df_parsed_data.shape)
df_parsed_data.head()
# Out:
# (2029, 42)
#                     id search_tag                           video_path
# 0  6892193566290889985  biden2020  data/videos/6892193566290889985.mp4  \
# 1  6839079433794505989  biden2020  data/videos/6839079433794505989.mp4
# 2  6885403130297732357  biden2020  data/videos/6885403130297732357.mp4
# 3  6889924077721521413  biden2020  data/videos/6889924077721521413.mp4
# 4  6891017029051108614  biden2020  data/videos/6891017029051108614.mp4
#
#    video_classes                                               desc
# 0            NaN  We'll be right, thanks. New Zealand.. anyone? ...  \
# 1            NaN  Reply to @nickh1940 #repost share this so more...
# 2            NaN  anyways vote biden💙#fyp #foryou #foryoupage #b...
# 3            NaN              Oh my god Barack Obama 🥵🥵🥵 #biden2020
# 4            NaN  Reply to @taybarnett262  IDK HOW TO FEEL RN HE...
#
#    create_time  is_duet_enabled
# 0   1604713867             True  \
# 1   1592347270             True
# 2   1603132900            False
# 3   1604185495             True
# 4   1604439965             True
#
#                                             hashtags
# 0         bidenharris2020, straya, aussie, biden2020  \
# 1  , repost, trump, viral, fyp, foryoupage, parat...
# 2                 fyp, foryou, foryoupage, biden2020
# 3                                          biden2020
# 4          , fyp, election2020, biden2020, trump2020
#
#                                                cover
# 0  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  \
# 1  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 2  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 3  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 4  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
#
#                                         play_address  ... author_digg_count
# 0  https://v16-webapp-prime.tiktok.com/video/tos/...  ...              7080  \
# 1  https://v16-webapp-prime.tiktok.com/video/tos/...  ...              9305
# 2  https://v16-webapp-prime.tiktok.com/video/tos/...  ...            100400
# 3  https://v16-webapp-prime.tiktok.com/video/tos/...  ...             14300
# 4  https://v16-webapp-prime.tiktok.com/video/tos/...  ...             78000
#
#    author_heart video_contains_music  video_contains_male
# 0      82800000                 True                 True  \
# 1       6600000                 True                 True
# 2      15700000                 True                False
# 3      81400000                 True                False
# 4       6200000                 True                 True
#
#   video_contains_female video_contains_noise video_contains_no_energy
# 0                  True                False                     True  \
# 1                 False                False                    False
# 2                 False                False                    False
# 3                 False                 True                    False
# 4                  True                 True                     True
#
#                                             segments  total_music_duration
# 0  [{'label': 'music', 'start': 0.0, 'end': 3.86}...                 3.860  \
# 1  [{'label': 'music', 'start': 0.0, 'end': 1.54}...                 1.540
# 2    [{'label': 'music', 'start': 0.0, 'end': 6.54}]                 6.540
# 3  [{'label': 'noise', 'start': 0.0, 'end': 3.9},...                12.840
# 4  [{'label': 'music', 'start': 0.0, 'end': 14.88...                14.880
#
#    percentage_of_video_made_of_music
# 0                             13.310
# 1                              6.696
# 2                            109.000
# 3                             80.250
# 4                             26.105
#
# [5 rows x 42 columns]

# %% [markdown]
# ## Selecting only 'EN' videos

# %%
df_transcripted_videos = df_transcripted_videos.loc[df_transcripted_videos['detected_language'] == 'en']

# %% [markdown]
# # Merging DataFrames

# %%
df_transcripted_videos = df_transcripted_videos.merge(df_parsed_data, how='left', right_on='id', left_on='audio_id')

# %% [markdown]
# ## Dealing with NaN

# %%
null_values = df_transcripted_videos.isnull().sum().sort_values(ascending=False)
null_values[null_values > 0]
# Out:
# author_avatar          1156
# author_signature       1156
# author_is_verified     1156
# video_classes          1156
# author_duet_setting    1156
# author_unique_id       1156
# author_nickname        1138
# stickers_on_video       508
# music_url                18
# transcription             4
# desc                      4
# music_author              3
# dtype: int64

# %%
df_transcripted_videos.dropna(subset=['transcription'], inplace=True)
df_transcripted_videos['stickers_on_video'].fillna('', inplace=True)
df_transcripted_videos['author_signature'].fillna('', inplace=True)
df_transcripted_videos['music_url'].fillna('', inplace=True)
df_transcripted_videos['music_author'].fillna('', inplace=True)

# %% [markdown]
# ## Datetime columns

# %%
df_transcripted_videos['create_time'] = pd.to_datetime(df_transcripted_videos['create_time'], unit='s')
df_transcripted_videos['create_time'] = df_transcripted_videos['create_time'].dt.tz_localize('UTC').dt.tz_convert('America/New_York')

# %% [markdown]
# # Creating new columns

# %%
# Column with video URL
df_transcripted_videos['video_url'] = 'https://www.tiktok.com/@' + df_transcripted_videos['author_unique_id'].fillna('') + '/video/' + df_transcripted_videos['id'].astype(str)

# %% [markdown]
# # Filtering columns

# %%
df_processed = df_transcripted_videos.loc[:, ['id', 'search_tag', 'create_time', 'desc', 'stickers_on_video', 'hashtags', 'duration', 
                                              'is_duet_enabled', 'duet_from_id', 'music_id', 'music_title', 'music_url', 'music_author', 
                                              'music_is_original_audio', 'digg_count', 'share_count', 'comment_count', 'play_count', 
                                              'author_unique_id', 'author_nickname', 'author_avatar', 'author_signature',
                                              'author_is_verified', 'author_duet_setting', 'author_following_count',
                                              'author_followers_count', 'author_heart_count', 'author_digg_count', 'author_heart',
                                              'video_path', 'video_url', 'transcription', 'video_contains_music', 'video_contains_male',
                                              'video_contains_female', 'video_contains_noise', 'video_contains_no_energy', 'segments',
                                              'total_music_duration', 'percentage_of_video_made_of_music']]
df_processed.head()
# Out:
#                     id search_tag               create_time
# 0  6746590978280279301   joebiden 2019-10-11 12:58:42-04:00  \
# 1  6748582567995378949       maga 2019-10-16 21:47:08-04:00
# 2  6752944407395175686  trump2020 2019-10-28 15:53:18-04:00
# 3  6755172553632926981  trump2020 2019-11-03 14:59:36-05:00
# 4  6758547542276852998       maga 2019-11-12 17:16:18-05:00
#
#                                                 desc
# 0  so the former Vice President and I are best bu...  \
# 1         “Your organization is terrible” #maga #fyp
# 2  The hat didn’t fit, but can the vid go viral s...
# 3  Keep America great #donaldtrump #trump2020 #tr...
# 4           #trump2020 #foryourpage #maga #maga #kag
#
#                stickers_on_video
# 0                                 \
# 1  Trump talking to CNN reporter
# 2
# 3                    Trump 20 20
# 4
#
#                                             hashtags  duration
# 0                               joebiden, foryoupage        32  \
# 1                                          maga, fyp        20
# 2                 fyp, foryou, trump2020, republican        10
# 3  donaldtrump, trump2020, trump, trumptrain, ins...        38
# 4            trump2020, foryourpage, maga, maga, kag        45
#
#    is_duet_enabled  duet_from_id             music_id  ...
# 0             True             0  6746567236959406853  ...  \
# 1             True             0  6748577002363652870  ...
# 2             True             0  6744484944707406597  ...
# 3             True             0  6755152356901423877  ...
# 4            False             0  6758505275898039046  ...
#
#                                            video_url
# 0  https://www.tiktok.com/@/video/674659097828027...  \
# 1  https://www.tiktok.com/@/video/674858256799537...
# 2  https://www.tiktok.com/@/video/675294440739517...
# 3  https://www.tiktok.com/@/video/675517255363292...
# 4  https://www.tiktok.com/@/video/675854754227685...
#
#                                        transcription video_contains_music
# 0  Do you know what Dab Me Up is? Do you know wha...                False  \
# 1  Go ahead, go ahead. No, not you, not you. Your...                False
# 2                                   There's not any.                 True
# 3  If I give you one message to hold in your hear...                 True
# 4    What? Did I kill them, sir? Are you kidding me?                 True
#
#    video_contains_male  video_contains_female  video_contains_noise
# 0                 True                  False                 False  \
# 1                 True                  False                 False
# 2                 True                  False                  True
# 3                 True                  False                 False
# 4                 True                  False                  True
#
#    video_contains_no_energy
# 0                     False  \
# 1                     False
# 2                      True
# 3                      True
# 4                     False
#
#                                             segments  total_music_duration
# 0    [{'label': 'male', 'start': 0.0, 'end': 32.92}]                 0.000  \
# 1  [{'label': 'male', 'start': 0.0, 'end': 20.580...                 0.000
# 2  [{'label': 'noise', 'start': 0.0, 'end': 2.260...                 4.540
# 3  [{'label': 'male', 'start': 0.0, 'end': 4.24},...                16.220
# 4  [{'label': 'music', 'start': 0.0, 'end': 11.46...                29.760
#
#   percentage_of_video_made_of_music
# 0                             0.000
# 1                             0.000
# 2                            45.400
# 3                            42.684
# 4                            66.133
#
# [5 rows x 40 columns]

# %%
print('Difference of columns of processed and transcripted dataset')
print(set(df_transcripted_videos.columns).difference(set(df_processed.columns)))
# Out:
# Difference of columns of processed and transcripted dataset
# {'play_address', 'download_address', 'cover', 'detected_language', 'audio_id', 'video_classes'}

# %% [markdown]
# # Renaming columns

# %%
df_processed.rename(columns={'hashtags': 'video_hashtags',
                             'desc': 'video_desc',
                             'duration': 'video_duration_in_sec'},
                    inplace=True, errors='raise')

# %% [markdown]
# # Saving dataframe

# %%
df_processed.to_csv('../data/processed/cleaned_transcripted_dataset.csv', index=False)
